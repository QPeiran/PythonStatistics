# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
ax = sns.lineplot(x="timepoint", y="signal", hue="event",
                  data=fmri)

# %%
newfmri = fmri.loc[((fmri["timepoint"] == 18) | (fmri["timepoint"] == 17)) & (fmri["event"] == 'stim') ]
newfmri
# Out:
#     subject  timepoint event    region    signal
# 0       s13         18  stim  parietal -0.017552
# 2       s12         18  stim  parietal -0.081033
# 3       s11         18  stim  parietal -0.046134
# 4       s10         18  stim  parietal -0.037970
# 5        s9         18  stim  parietal -0.103513
# 6        s8         18  stim  parietal -0.064408
# 7        s7         18  stim  parietal -0.060526
# 8        s6         18  stim  parietal -0.007029
# 9        s5         18  stim  parietal -0.040557
# 10       s4         18  stim  parietal -0.048812
# 11       s3         18  stim  parietal -0.047148
# 12       s2         18  stim  parietal -0.086623
# 13       s1         18  stim  parietal -0.046659
# 14       s0         18  stim  parietal -0.075570
# 15      s13         17  stim  parietal -0.008265
# 16      s12         17  stim  parietal -0.088512
# 18      s10         17  stim  parietal -0.016847
# 19       s9         17  stim  parietal -0.121574
# 20       s8         17  stim  parietal -0.076287
# 21       s7         17  stim  parietal -0.043812
# 22       s6         17  stim  parietal -0.014746
# 23       s5         17  stim  parietal -0.056682
# 24       s4         17  stim  parietal -0.044582
# 25       s3         17  stim  parietal -0.053514
# 26       s2         17  stim  parietal -0.077292
# 27       s1         17  stim  parietal -0.038021
# 28       s0         17  stim  parietal -0.071300
# 65      s11         17  stim  parietal -0.041960
# 498      s0         17  stim   frontal -0.039322
# 502      s2         18  stim   frontal -0.058471
# 504      s2         17  stim   frontal -0.049078
# 505      s3         17  stim   frontal -0.014400
# 506      s4         17  stim   frontal -0.062506
# 507      s5         17  stim   frontal -0.029921
# 508      s6         17  stim   frontal  0.038575
# 509      s7         17  stim   frontal  0.001212
# 510      s8         17  stim   frontal -0.042657
# 511      s9         17  stim   frontal -0.030099
# 512     s11         17  stim   frontal -0.025345
# 513     s12         17  stim   frontal -0.060134
# 514     s13         17  stim   frontal  0.023494
# 515      s0         18  stim   frontal -0.048430
# 516      s1         18  stim   frontal -0.035852
# 517     s10         17  stim   frontal -0.004571
# 518      s3         18  stim   frontal -0.010920
# 519      s9         18  stim   frontal -0.009959
# 520      s1         17  stim   frontal -0.015686
# 522     s13         18  stim   frontal  0.024425
# 523     s12         18  stim   frontal -0.062332
# 524     s11         18  stim   frontal -0.030784
# 525     s10         18  stim   frontal -0.008928
# 527      s8         18  stim   frontal -0.011114
# 528      s6         18  stim   frontal  0.046500
# 529      s5         18  stim   frontal -0.031013
# 530      s4         18  stim   frontal -0.063263
# 531      s7         18  stim   frontal -0.019634

# %%
bx = sns.lineplot(x="timepoint", y="signal", hue="event",
                  data=newfmri)
